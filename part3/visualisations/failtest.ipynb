# %%
import pandas as pd
import matplotlib.pyplot as plt
fail  = pd.read_csv("fail.csv")
#spv  = pd.read_csv("spv-time.csv")
#result = pd.merge(scv,spv,right_index=True, left_index=True)
toplot = fail[['scv success rate','spv success rate']]
toplot.plot()
#plt.plot(toplot)
#plt.ylim(0.5,1.1)
# Out:
# <AxesSubplot:>
