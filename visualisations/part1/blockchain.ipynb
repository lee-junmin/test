# %%
import pandas as pd
import matplotlib.pyplot as plt
scv  = pd.read_csv("scv-time.csv")
spv  = pd.read_csv("spv-time.csv")
result = pd.merge(scv,spv,right_index=True, left_index=True)
result.plot()
#spv.plot()
# Out:
# &lt;AxesSubplot:&gt;
# &lt;Figure size 432x288 with 1 Axes&gt;

# %%
toPlot  = pd.read_csv("scv-step.csv")
toPlot.plot()
plt.ylim(0,24)
#toPlot  = pd.read_csv("scv-time.csv")
#toPlot.plot(kind='line')
#plt.plot(toplot)
# Out:
# (0.0, 24.0)
# &lt;Figure size 432x288 with 1 Axes&gt;

# %%
toPlot  = pd.read_csv("spv-step.csv")
toPlot.plot()
toPlot  = pd.read_csv("spv-time.csv")
toPlot.plot()
# Out:
# &lt;AxesSubplot:&gt;
# &lt;Figure size 432x288 with 1 Axes&gt;
# &lt;Figure size 432x288 with 1 Axes&gt;

# %%
scv  = pd.read_csv("scv-step.csv")
spv  = pd.read_csv("spv-step.csv")
result = pd.merge(scv,spv,right_index=True, left_index=True)
result.plot()
plt.ylim(0,200)
plt.xlim(0,10)
# Out:
# (0.0, 10.0)
# &lt;Figure size 432x288 with 1 Axes&gt;

# %%
import pandas as pd
import numpy as np
from scipy import stats

level  = pd.read_csv("../../level.csv")
stats.describe(level)
# Out:
# DescribeResult(nobs=1000, minmax=(array([0]), array([12])), mean=array([4.073]), variance=array([3.54121221]), skewness=array([0.38682001]), kurtosis=array([0.09627896]))
